# %% [markdown]
# # ALGORITHME DES K PLUS PROCHES VOISINS

# %% [markdown]
# ## L'algorithme des k plus proches voisins est un algorithme dit d’apprentissage automatique qui permet à un programme d’apprendre à classer des « objets » en utilisant un jeu de données pour qu’il y trouve des similarités. Il s’agit d’un algorithme simple de « machine learning » un sujet très en vogue à l’heure actuelle dans le domaine de l’informatique.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Comment classer le point vert ? Si k = 3 (cercle en ligne pleine) il est classé comme un triangle car il y a deux triangles et seulement un carré dans le cercle considéré. Si k = 5 (cercle en ligne pointillée) il est classé comme un carré (3 carrés face à deux triangles dans le cercle externe).

# %% [markdown]
# ## Principe de l’apprentissage supervisé

# %% [markdown]
# On se base souvent sur l’utilisation de données annotées que l’on fournit à l’ordinateur pour qu’il y trouve des similarités.
# C’est ce qui est appelé l’__apprentissage supervisé__.

# %% [markdown]
# <u>**Exemple**</u> :

# %% [markdown]
# On peut fournir à un programme une grande quantité d’écritures de chiffres.<br>
#
# Le programme va lire toutes les données, et grâce à des algorithmes plus ou moins évolués, le programme va trouver les points communs entre les chiffres représentant le même nombre.

# %% [markdown]
# ![MnistExamples.png](data:image/png;base64,...)

# %% [markdown]
# Le jeu de données du MNIST est un exemple de jeu d'entrainement et de tests des algorithmes de reconnaissance de chiffres. <br>
# ©  CC BY-SA 4.0 via Wikimedia Commons

# %% [markdown]
# Ensuite, on peut donner au programme une image non annotée, et il nous dira s’il s’agit d’un 1, d’un 6 ou d’un 8… <br>
#
# C’est un système qui est utilisé depuis des années pour la lecture des codes postaux sur les lettres avec une efficacité supérieure à 99%.

# %% [markdown]
# ## Principe l’algorithme des k plus proches voisins

# %% [markdown]
# On dispose d’une collection de données annotées, et on veut savoir à quelle catégorie appartient un nouvel échantillon. Il s’agit d’un problème de **classification**.

# %% [markdown]
# <iframe src="https://hmalherbe.fr/thalesm/gestclasse/documents/Premiere_NSI/Animations/k_plus_proches_voisins/k_plus_proches_voisins.html" title="description" width="1000" height="1000"></iframe>

# %% [markdown]
# Consultez cette animation qui illustre l'algorithme des k plus proches voisins :
# https://hmalherbe.fr/thalesm/gestclasse/documents/Premiere_NSI/Animations/k_plus_proches_voisins/k_plus_proches_voisins.html

# %% [markdown]
# Nous allons travailler sur un tableau de données des joueurs de rugby du top-14 de la saison 2019-2020 issues de la page de la ligue nationale de rugby :
#
# [fichier csv](https://drive.google.com/file/d/1TwwFmnxO8hWhMq451IZr1YN5cFSrdaty/view?usp=sharing)
#
# Le travail consistera à attribuer un poste sur le terrain à un joueur à partir de son poids et de sa taille en utilisant l’algorithme des k plus proches voisins:
#
# * avant ;
# * deuxième ligne,
# * troisième ligne,
# * demi ;
# * trois-quart ;
# * arrière

# %% [markdown]
# ## Lecture des données

# %% [markdown]
# On commence par lire les données du fichier sous la forme d’un tableau de tableau.

# %%
import csv
NOM_FICHIER_CSV = "JoueursTop14.csv"
# NOM_FICHIER_CSV = "/content/drive/MyDrive/Colab Notebooks/NSI/Première/knn/JoueursTop14.csv"

def extractionDonnees(nom_fichier):
    f = open(nom_fichier, encoding="utf8")
    lignes = csv.reader(f,delimiter=";")
    tabJoueurs = []
    return [ligne for ligne in lignes][1:]

donnees = extractionDonnees(NOM_FICHIER_CSV)
for d in donnees:
  print(d)
#
# Out:
# ['Agen', 'Anton PEIKRISHVILI', 'Avant', '18/09/1987', '183', '122']
# ['Agen', 'Dave RYAN', 'Avant', '21/04/1986', '183', '116']
# ['Agen', 'Giorgi TETRASHVILI', 'Avant', '31/08/1993', '177', '112']
# ['Agen', 'Kamaliele TUFELE', 'Avant', '11/10/1995', '182', '123']
# ['Agen', 'Malino VANAÏ', 'Avant', '04/05/1993', '183', '119']
# ['Agen', 'Morgan PHÉLIPPONNEAU', 'Avant', '05/09/1989', '185', '106']
# ['Agen', 'Walter DESMAISON', 'Avant', '18/10/1991', '188', '119']
# ['Agen', 'Clément MARTINEZ', 'Avant', '14/03/1996', '181', '105']
# ['Agen', 'Marc BARTHOMEUF', 'Avant', '19/07/1991', '174', '100']
# ['Agen', 'Paula NGAUAMO', 'Avant', '19/02/1990', '182', '117']
# ['Agen', 'Adrian MOTOC', '2ème ligne', '11/07/1996', '197', '108']
# ['Agen', 'Andrés ZAFRA', '2ème ligne', '26/03/1996', '197', '116']
# ['Agen', 'Mickaël DE MARCO', '2ème ligne', '22/04/1989', '195', '134']
# ['Agen', 'Pierce PHILLIPS', '2ème ligne', '06/10/1992', '203', '119']
# ['Agen', 'Tom MURDAY', '2ème ligne', '27/04/1989', '200', '114']
# ['Agen', 'Dylan HAYES', '3ème ligne', '11/02/1994', '194', '114']
# ['Agen', 'Laurence PEARCE', '3ème ligne', '03/12/1990', '192', '120']
# ['Agen', 'Romain BRIATTE', '3ème ligne', '18/02/1993', '194', '105']
# ['Agen', 'Vincent FARRÉ', '3ème ligne', '06/06/1990', '193', '103']
# ['Agen', 'Hugo VERDU', 'Demi', '24/10/1996', '176', '82']
# ['Agen', 'Paul ABADIE', 'Demi', '28/07/1994', '176', '88']
# ['Agen', 'Xavier CHAUVEAU', 'Demi', '14/10/1992', '180', '84']
# ['Agen', 'Raphaël LAGARDE', 'Demi', '30/10/1988', '182', '92']
# ['Agen', 'Alban CONDUCHÉ', 'Trois-Quarts', '29/10/1996', '190', '102']
# ['Agen', 'Johann SADIE', 'Trois-Quarts', '23/01/1989', '188', '96']
# ['Agen', 'Jordan PULETUA', 'Trois-Quarts', '28/02/1990', '193', '105']
# ['Agen', 'Sam VAKA', 'Trois-Quarts', '26/10/1992', '187', '98']
# ['Agen', 'Benito MASILEVU', 'Trois-Quarts', '07/10/1989', '178', '83']
# ['Agen', 'Julien JANÉ', 'Trois-Quarts', '12/09/1989', '186', '100']
# ['Agen', 'Timilai ROKODURU', 'Trois-Quarts', '21/01/1993', '191', '113']
# ['Agen', 'Valentin SAURS', 'Trois-Quarts', '12/02/1995', '182', '82']
# ['Agen', 'JJ TAULAGI', 'Arrière', '18/06/1993', '180', '90']
# ['Agen', 'Loris TOLOT', 'Arrière', '03/03/1993', '185', '90']
# ['Agen', 'Mathieu LAMOULIE', 'Arrière', '07/08/1990', '184', '93']
# ['Bayonne', 'Aretz IGUINIZ', 'Avant', '03/06/1983', '188', '114']
# ['Bayonne', 'Census JOHNSTON', 'Avant', '06/05/1981', '189', '130']
# ['Bayonne', 'Jean-Baptiste DE CLERCQ', 'Avant', '23/02/1994', '183', '115']
# ['Bayonne', 'Jon ZABALA', 'Avant', '26/11/1996', '192', '128']
# ['Bayonne', 'Luc MOUSSET', 'Avant', '03/04/1994', '180', '115']
# ['Bayonne', 'Swan CORMENIER', 'Avant', '10/01/1996', '178', '117']
# ['Bayonne', "Toma'Akino TAUFA", 'Avant', '09/03/1995', '180', '125']
# ['Bayonne', 'Ugo BONIFACE', 'Avant', '21/07/1998', '190', '125']
# ['Bayonne', 'Viliamu AFATIA', 'Avant', '24/05/1990', '189', '124']
# ['Bayonne', 'Maxime DELONCA', 'Avant', '29/04/1988', '180', '107']
# ['Bayonne', 'Maxime LAMOTHE', 'Avant', '03/10/1998', '184', '109']
# ['Bayonne', 'Torsten VAN JAARSVELD', 'Avant', '30/06/1987', '175', '106']
# ['Bayonne', 'Adam JAULHAC', '2ème ligne', '31/01/1988', '198', '125']
# ['Bayonne', 'Bastien BERGOUNIOUX', '2ème ligne', '18/06/1996', '202', '100']
# ['Bayonne', 'Edwin MAKA', '2ème ligne', '25/01/1993', '196', '140']
# ['Bayonne', 'Evrard Dion OULAI', '2ème ligne', '22/06/1993', '198', '125']
# ['Bayonne', 'Guillaume DUCAT', '2ème ligne', '20/05/1996', '205', '115']
# ['Bayonne', 'Mariano GALARZA', '2ème ligne', '11/12/1986', '202', '114']
# ['Bayonne', 'Pieter Jan VAN LILL', '2ème ligne', '04/12/1983', '193', '120']
# ['Bayonne', 'André GORIN', '3ème ligne', '30/11/1987', '192', '111']
# ['Bayonne', 'Antoine BATTUT', '3ème ligne', '01/01/1984', '192', '104']
# ['Bayonne', 'Armandt KOSTER', '3ème ligne', '20/01/1990', '192', '114']
# ['Bayonne', 'Arnaud DUPUTS', '3ème ligne', '26/07/1995', '188', '98']
# ['Bayonne', 'Baptiste HÉGUY', '3ème ligne', '11/05/1998', '196', '97']
# ['Bayonne', 'Benjamin COLLET', '3ème ligne', '11/04/1989', '184', '103']
# ['Bayonne', 'Filimo TAOFIFENUA', '3ème ligne', '15/10/1993', '188', '100']
# ['Bayonne', 'Jean MONRIBOT', '3ème ligne', '11/10/1987', '183', '99']
# ['Bayonne', 'Mat LUAMANU', '3ème ligne', '04/03/1988', '193', '127']
# ['Bayonne', 'Tom DARLET', '3ème ligne', '06/08/1996', '188', '104']
# ['Bayonne', 'Emmanuel SAUBUSSE', 'Demi', '23/11/1989', '181', '84']
# ['Bayonne', 'Guillaume ROUET', 'Demi', '13/08/1988', '170', '75']
# ['Bayonne', 'Michael RURU', 'Demi', '03/12/1990', '182', '93']
# ['Bayonne', 'Brandon FAJARDO', 'Demi', '25/06/1994', '181', '77']
# ['Bayonne', 'Manuel ORDAS', 'Demi', '21/02/1998', '186', '83']
# ['Bayonne', 'Alofa ALOFA', 'Trois-Quarts', '12/03/1991', '185', '95']
# ['Bayonne', 'Callum WILSON', 'Trois-Quarts', '28/10/1990', '182', '95']
# ['Bayonne', 'Maile MAMAO', 'Trois-Quarts', '07/01/1996', '187', '117']
# ['Bayonne', 'Malietoa HINGANO', 'Trois-Quarts', '27/01/1992', '180', '95']
# ['Bayonne', 'Peyo MUSCARDITZ', 'Trois-Quarts', '02/01/1996', '174', '88']
# ['Bayonne', 'Romain BARTHÉLÉMY', 'Trois-Quarts', '25/01/1990', '186', '97']
# ['Bayonne', 'Arthur DUHAU', 'Trois-Quarts', '09/08/1997', '181', '86']
# ['Bayonne', 'Djibril CAMARA', 'Trois-Quarts', '22/06/1989', '183', '90']
# ['Bayonne', 'Sean ROBINSON', 'Trois-Quarts', '02/11/1993', '181', '90']
# ['Bayonne', 'Aymeric LUC', 'Arrière', '14/10/1997', '180', '76']
# ['Bayonne', 'Johannes Petrus GRAAFF', 'Arrière', '10/09/1989', '179', '77']
# ['Bayonne', 'Julien TISSERON', 'Arrière', '12/08/1995', '182', '82']
# ['Bordeaux', 'Jefferson POIROT', 'Avant', '01/11/1992', '181', '117']
# ['Bordeaux', 'Lasha TABIDZE', 'Avant', '04/07/1997', '185', '117']
# ['Bordeaux', 'Laurent DELBOULBÈS', 'Avant', '17/11/1986', '181', '106']
# ['Bordeaux', 'Lekso KAULASHVILI', 'Avant', '27/08/1992', '187', '120']
# ['Bordeaux', 'Peni RAVAI', 'Avant', '16/06/1990', '185', '119']
# ['Bordeaux', 'Thierry PAÏVA', 'Avant', '19/11/1995', '184', '125']
# ['Bordeaux', 'Vadim COBILAS', 'Avant', '30/07/1983', '180', '118']
# ['Bordeaux', 'Adrien PÉLISSIÉ', 'Avant', '07/08/1990', '181', '110']
# ['Bordeaux', 'Clément MAYNADIER', 'Avant', '11/10/1988', '187', '100']
# ['Bordeaux', 'Alexandre FLANQUART', '2ème ligne', '09/10/1989', '204', '120']
# ['Bordeaux', 'Cyril CAZEAUX', '2ème ligne', '10/02/1995', '198', '113']
# ['Bordeaux', 'Jandré MARAIS', '2ème ligne', '14/06/1989', '198', '118']
# ['Bordeaux', 'Kane DOUGLAS', '2ème ligne', '01/06/1989', '202', '123']
# ['Bordeaux', 'Masalosalo TUTAIA', '2ème ligne', '05/06/1984', '204', '125']
# ['Bordeaux', 'Afa AMOSA', '3ème ligne', '11/10/1990', '187', '112']
# ['Bordeaux', 'Alexandre ROUMAT', '3ème ligne', '27/06/1997', '198', '104']
# ['Bordeaux', 'Béka GORGADZE', '3ème ligne', '08/02/1996', '189', '105']
# ['Bordeaux', 'Cameron WOKI', '3ème ligne', '07/11/1998', '196', '103']
# ['Bordeaux', 'Mahamadou DIABY', '3ème ligne', '15/08/1990', '188', '105']
# ['Bordeaux', 'Marco TAULEIGNE', '3ème ligne', '30/08/1993', '191', '115']
# ['Bordeaux', 'Scott HIGGINBOTHAM', '3ème ligne', '05/09/1986', '195', '110']
# ['Bordeaux', 'Maxime LUCU', 'Demi', '12/01/1993', '177', '79']
# ['Bordeaux', 'Yann LESGOURGUES', 'Demi', '17/01/1991', '174', '71']
# ['Bordeaux', 'Ben BOTICA', 'Demi', '07/10/1989', '178', '93']
# ['Bordeaux', 'Lucas MÉRET', 'Demi', '30/01/1995', '178', '85']
# ['Bordeaux', 'Matthieu JALIBERT', 'Demi', '06/11/1998', '180', '79']
# ['Bordeaux', 'Jean-Baptiste DUBIÉ', 'Trois-Quarts', '16/07/1989', '181', '85']
# ['Bordeaux', 'Rémi LAMERAT', 'Trois-Quarts', '14/01/1990', '184', '105']
# ['Bordeaux', 'Semi RADRADRA', 'Trois-Quarts', '13/06/1992', '188', '102']
# ['Bordeaux', 'Seta TAMANIVALU', 'Trois-Quarts', '23/07/1992', '189', '110']
# ['Bordeaux', 'Ulupano SEUTENI', 'Trois-Quarts', '09/12/1993', '185', '95']
# ['Bordeaux', 'Blair CONNOR', 'Trois-Quarts', '29/09/1988', '183', '82']
# ['Bordeaux', 'Nicolas PLAZY', 'Trois-Quarts', '17/05/1994', '188', '85']
# ['Bordeaux', 'Santiago CORDERO', 'Trois-Quarts', '06/12/1993', '177', '83']
# ['Bordeaux', 'Geoffrey CROS', 'Arrière', '08/03/1997', '185', '85']
# ['Bordeaux', 'Nans DUCUING', 'Arrière', '06/11/1991', '181', '90']
# ['Bordeaux', 'Romain BUROS', 'Arrière', '31/07/1997', '187', '91']
# ['Brive', 'Cody THOMAS', 'Avant', '01/03/1996', '186', '124']
# ['Brive', 'Hayden THOMPSON-STRINGER', 'Avant', '25/12/1994', '190', '119']
# ['Brive', 'James JOHNSTON', 'Avant', '06/03/1986', '191', '129']
# ['Brive', 'Karlen ASIESHVILI', 'Avant', '21/04/1987', '180', '118']
# ['Brive', 'Mesake DOGE', 'Avant', '01/04/1993', '178', '122']
# ['Brive', 'Simon-Pierre CHAUVAC', 'Avant', '23/03/1998', '189', '116']
# ['Brive', 'Soso BEKOSHVILI', 'Avant', '03/11/1993', '180', '116']
# ['Brive', 'François DA ROS', 'Avant', '29/09/1983', '179', '104']
# ['Brive', 'Peniami Nasali NARISIA', 'Avant', '10/06/1997', '187', '104']
# ['Brive', 'Thomas ACQUIER', 'Avant', '21/11/1989', '181', '112']
# ['Brive', 'Jan UYS', '2ème ligne', '03/01/1994', '195', '120']
# ['Brive', 'Joe SNYMAN', '2ème ligne', '09/07/1986', '200', '112']
# ['Brive', 'Mitch LEES', '2ème ligne', '12/10/1988', '196', '120']
# ['Brive', 'Peet MARAIS', '2ème ligne', '31/10/1990', '199', '120']
# ['Brive', 'Richard FOURCADE', '2ème ligne', '04/04/1993', '200', '110']
# ['Brive', 'Victor LEBAS', '2ème ligne', '09/06/1993', '193', '108']
# ['Brive', 'Esteban ABADIE', '3ème ligne', '01/12/1997', '188', '95']
# ['Brive', 'Irakli TSKHADADZE', '3ème ligne', '01/08/1996', '191', '104']
# ['Brive', 'Kitione KAMIKAMICA', '3ème ligne', '27/04/1996', '188', '105']
# ['Brive', 'Matthieu VOISIN', '3ème ligne', '16/05/1996', '193', '104']
# ['Brive', 'Otar GIORGADZE', '3ème ligne', '02/03/1996', '193', '108']
# ['Brive', 'Saïd HIRÈCHE', '3ème ligne', '27/05/1985', '183', '102']
# ['Brive', "So'otala FA'ASO'O", '3ème ligne', '02/10/1994', '194', '127']
# ['Brive', 'Steevy CERQUEIRA', '3ème ligne', '09/08/1993', '206', '114']
# ['Brive', 'David DELARUE', 'Demi', '27/10/1996', '190', '85']
# ['Brive', 'Julien BLANC', 'Demi', '04/10/1992', '175', '81']
# ['Brive', 'Quentin DELORD', 'Demi', '10/02/1999', '171', '74']
# ['Brive', 'Vasil LOBZHANIDZE', 'Demi', '14/10/1996', '175', '75']
# ['Brive', 'Enzo HERVÉ', 'Demi', '13/10/1998', '177', '89']
# ['Brive', 'Thomas LARANJEIRA', 'Demi', '05/05/1992', '186', '90']
# ['Brive', 'Alban RAMETTE', 'Trois-Quarts', '07/10/1998', '188', '91']
# ['Brive', 'Alex DUNBAR', 'Trois-Quarts', '23/04/1990', '191', '103']
# ['Brive', 'Arnaud MIGNARDI', 'Trois-Quarts', '01/11/1986', '180', '90']
# ['Brive', 'Guillaume GALLETIER', 'Trois-Quarts', '07/03/1997', '178', '98']
# ['Brive', 'Nico LEE', 'Trois-Quarts', '13/03/1994', '180', '89']
# ['Brive', 'Seva GALALA', 'Trois-Quarts', '29/01/1993', '188', '105']
# ['Brive', 'Stuart OLDING', 'Trois-Quarts', '11/03/1993', '180', '87']
# ['Brive', 'Axel MULLER', 'Trois-Quarts', '25/11/1993', '186', '94']
# ['Brive', 'Franck ROMANET', 'Trois-Quarts', '02/05/1986', '178', '89']
# ['Brive', 'Guillaume NAMY', 'Trois-Quarts', '03/04/1989', '182', '83']
# ['Brive', 'Rory SCHOLES', 'Trois-Quarts', '23/04/1993', '186', '95']
# ['Brive', 'Setareki BITUNIYATA', 'Trois-Quarts', '12/08/1995', '190', '89']
# ['Brive', 'Joris JURAND', 'Arrière', '11/11/1995', '188', '106']
# ['Brive', 'Rico BULIRUARUA', 'Arrière', '23/01/1997', '186', '106']
# ['Castres', 'Antoine TICHIT', 'Avant', '13/06/1989', '182', '112']
# ['Castres', 'Daniel KOTZE', 'Avant', '28/03/1987', '187', '120']
# ['Castres', 'Karena WIHONGI', 'Avant', '29/09/1979', '186', '130']
# ['Castres', 'Marc CLERC', 'Avant', '09/06/1987', '181', '120']
# ['Castres', 'Matt TIERNEY', 'Avant', '04/07/1996', '191', '132']
# ['Castres', "Paea FA'ANUNU", 'Avant', '04/11/1988', '191', '125']
# ['Castres', 'Tapu FALATEA', 'Avant', '12/12/1988', '187', '137']
# ['Castres', 'Tudor STROË', 'Avant', '06/09/1993', '184', '112']
# ['Castres', 'Wayan DE BENEDITTIS', 'Avant', '10/03/1999', '185', '107']
# ['Castres', 'Wilfrid HOUNKPATIN', 'Avant', '29/07/1991', '192', '132']
# ['Castres', 'Jody JENNEKER', 'Avant', '10/04/1984', '185', '106']
# ['Castres', 'Kévin FIRMIN', 'Avant', '20/04/1992', '183', '105']
# ['Castres', 'Marc-Antoine RALLIER', 'Avant', '02/12/1988', '182', '107']
# ['Castres', 'Paul SAUZARET', 'Avant', '04/03/1997', '184', '107']
# ['Castres', 'Christophe SAMSON', '2ème ligne', '01/03/1984', '198', '107']
# ['Castres', "Hans N'KINSI", '2ème ligne', '21/09/1992', '195', '115']
# ['Castres', 'Loïc JACQUET', '2ème ligne', '31/03/1985', '198', '117']
# ['Castres', 'Rodrigo CAPO ORTEGA', '2ème ligne', '08/12/1980', '195', '110']
# ['Castres', 'Victor MOREAUX', '2ème ligne', '19/09/1993', '200', '123']
# ['Castres', 'Alex TULOU', '3ème ligne', '21/03/1987', '192', '114']
# ['Castres', 'Anthony JELONCH', '3ème ligne', '28/07/1996', '193', '105']
# ['Castres', 'Baptiste DELAPORTE', '3ème ligne', '27/03/1997', '190', '112']
# ['Castres', 'Camille GÉRONDEAU', '3ème ligne', '12/03/1988', '194', '113']
# ['Castres', 'Dorian CLERC', '3ème ligne', '07/07/1998', '194', '110']
# ['Castres', 'Kévin GIMENO', '3ème ligne', '11/09/1991', '195', '106']
# ['Castres', "Ma'ama VAIPULU", '3ème ligne', '21/07/1989', '190', '112']
# ['Castres', 'Mathieu BABILLOT', '3ème ligne', '09/09/1993', '190', '111']
# ['Castres', 'Ludovic RADOSAVLJEVIC', 'Demi', '17/08/1989', '180', '95']
# ['Castres', 'Rory KOCKOTT', 'Demi', '25/06/1986', '180', '92']
# ['Castres', 'Benjamin URDAPILLETA', 'Demi', '11/03/1986', '178', '86']
# ['Castres', 'Thomas FORTUNEL', 'Demi', '07/06/1995', '177', '76']
# ['Castres', 'Florian VIALELLE', 'Trois-Quarts', '05/10/1993', '185', '88']
# ['Castres', 'Robert EBERSOHN', 'Trois-Quarts', '23/02/1989', '180', '89']
# ['Castres', 'Thomas COMBEZOU', 'Trois-Quarts', '26/01/1987', '184', '94']
# ['Castres', 'Yann DAVID', 'Trois-Quarts', '15/04/1988', '185', '102']
# ['Castres', 'Armand BATLLE', 'Trois-Quarts', '12/04/1987', '188', '92']
# ['Castres', 'Benjamin LAPEYRE', 'Trois-Quarts', '24/09/1986', '181', '87']
# ['Castres', 'Filipo NAKOSI', 'Trois-Quarts', '08/04/1992', '182', '98']
# ['Castres', 'Julien CAMINATI', 'Trois-Quarts', '28/10/1985', '178', '88']
# ['Castres', 'Martin LAVEAU', 'Trois-Quarts', '10/09/1996', '182', '78']
# ['Castres', 'Taylor PARIS', 'Trois-Quarts', '06/10/1992', '185', '93']
# ['Castres', 'Geoffrey PALIS', 'Arrière', '08/07/1991', '189', '93']
# ['Castres', 'Julien DUMORA', 'Arrière', '24/03/1988', '184', '96']
# ['Clermont', 'Beqa KAKABADZE', 'Avant', '07/09/1995', '181', '110']
# ['Clermont', 'Davit ZIRAKASHVILI', 'Avant', '10/10/1983', '179', '120']
# ['Clermont', 'Duane AHOLELEI', 'Avant', '16/02/1989', '189', '130']
# ['Clermont', 'Etienne FALGOUX', 'Avant', '19/01/1993', '182', '112']
# ['Clermont', 'Giorgi BERIA', 'Avant', '11/11/1999', '175', '107']
# ['Clermont', 'Loni UHILA', 'Avant', '07/04/1989', '182', '125']
# ['Clermont', 'Rabah SLIMANI', 'Avant', '18/10/1989', '178', '113']
# ['Clermont', 'Sipili FALATEA', 'Avant', '06/06/1997', '184', '116']
# ['Clermont', 'John ULUGIA', 'Avant', '17/01/1986', '180', '115']
# ['Clermont', 'Mike TADJER', 'Avant', '10/03/1989', '183', '110']
# ['Clermont', 'Yohan BEHEREGARAY', 'Avant', '29/05/1996', '180', '102']
# ['Clermont', 'Clément LANEN', '2ème ligne', '01/04/1998', '196', '103']
# ['Clermont', 'George MERRICK', '2ème ligne', '04/10/1992', '201', '126']
# ['Clermont', 'Jaco VAN TONDER', '2ème ligne', '03/03/1998', '197', '118']
# ['Clermont', 'Paul JEDRASIAK', '2ème ligne', '06/02/1993', '200', '118']
# ['Clermont', 'Sébastien VAHAAMAHINA', '2ème ligne', '21/10/1991', '203', '120']
# ['Clermont', 'Sitaleki TIMANI', '2ème ligne', '19/09/1986', '203', '120']
# ['Clermont', 'Alexandre FISCHER', '3ème ligne', '19/01/1998', '188', '103']
# ['Clermont', 'Alexandre LAPANDRY', '3ème ligne', '13/04/1989', '194', '101']
# ['Clermont', 'Arthur ITURRIA', '3ème ligne', '13/05/1994', '198', '112']
# ['Clermont', 'Faifili LEVAVE', '3ème ligne', '15/01/1986', '193', '111']
# ['Clermont', 'Fritz LEE', '3ème ligne', '29/08/1988', '188', '107']
# ['Clermont', 'Judicaël CANCORIET', '3ème ligne', '25/04/1996', '194', '112']
# ['Clermont', 'Peceli YATO', '3ème ligne', '17/01/1993', '196', '120']
# ['Clermont', 'Charlie CASSANG', 'Demi', '08/02/1995', '173', '84']
# ['Clermont', 'Greig LAIDLAW', 'Demi', '12/10/1985', '176', '78']
# ['Clermont', 'Morgan PARRA', 'Demi', '15/11/1988', '180', '81']
# ['Clermont', 'Rudy PAIGE', 'Demi', '02/08/1989', '169', '77']
# ['Clermont', 'Camille LOPEZ', 'Demi', '03/04/1989', '176', '87']
# ['Clermont', 'Jake MCINTYRE', 'Demi', '28/04/1994', '177', '88']
# ['Clermont', 'Apisai NAQALEVU', 'Trois-Quarts', '21/08/1989', '188', '104']
# ['Clermont', 'George MOALA', 'Trois-Quarts', '05/11/1990', '187', '104']
# ['Clermont', 'JJ ENGELBRECHT', 'Trois-Quarts', '22/02/1989', '190', '94']
# ['Clermont', 'Wesley FOFANA', 'Trois-Quarts', '20/01/1988', '182', '93']
# ['Clermont', 'Alivereti RAKA', 'Trois-Quarts', '09/12/1994', '189', '97']
# ['Clermont', 'Damian PENAUD', 'Trois-Quarts', '25/09/1996', '192', '94']
# ['Clermont', 'Peter BETHAM', 'Trois-Quarts', '06/01/1989', '191', '98']
# ['Clermont', 'Rémy GROSSO', 'Trois-Quarts', '04/12/1988', '191', '104']
# ['Clermont', 'Samuel EZEALA', 'Trois-Quarts', '11/12/1999', '187', '94']
# ['Clermont', 'Tim NANAI-WILLIAMS', 'Trois-Quarts', '12/06/1989', '182', '90']
# ['Clermont', 'Isaia TOEAVA', 'Arrière', '15/01/1986', '181', '100']
# ['Clermont', 'Nick ABENDANON', 'Arrière', '27/08/1986', '178', '83']
# ['Clermont', 'Setariki TUICUVU', 'Arrière', '07/09/1995', '179', '94']
# ['La Rochelle', 'Arthur JOLY', 'Avant', '20/02/1988', '189', '123']
# ['La Rochelle', 'Dany PRISO', 'Avant', '02/01/1994', '182', '110']
# ['La Rochelle', 'Mike CORBEL', 'Avant', '09/04/1992', '179', '118']
# ['La Rochelle', 'Ramiro HERRERA', 'Avant', '14/02/1989', '194', '123']
# ['La Rochelle', 'Reda WARDI', 'Avant', '02/08/1995', '185', '110']
# ['La Rochelle', 'Sila PUAFISI', 'Avant', '15/04/1988', '183', '128']
# ['La Rochelle', 'Uini ATONIO', 'Avant', '26/03/1990', '196', '152']
# ['La Rochelle', 'Vincent PELO', 'Avant', '22/04/1988', '187', '130']
# ['La Rochelle', 'Facundo BOSCH', 'Avant', '08/08/1991', '180', '100']
# ['La Rochelle', 'Jean-Charles ORIOLI', 'Avant', '09/08/1989', '179', '110']
# ['La Rochelle', 'Pierre BOURGARIT', 'Avant', '12/09/1997', '184', '105']
# ['La Rochelle', 'Jone QOVU', '2ème ligne', '26/07/1985', '197', '134']
# ['La Rochelle', 'Mathieu TANGUY', '2ème ligne', '05/06/1996', '195', '110']
# ['La Rochelle', 'Romain SAZY', '2ème ligne', '14/10/1986', '199', '105']
# ['La Rochelle', 'Thomas JOLMÈS', '2ème ligne', '08/10/1995', '204', '116']
# ['La Rochelle', 'Thomas LAVAULT', '2ème ligne', '03/05/1999', '199', '105']
# ['La Rochelle', 'Kévin GOURDON', '3ème ligne', '23/01/1990', '190', '103']
# ['La Rochelle', 'Lopeti TIMANI', '3ème ligne', '28/09/1990', '193', '124']
# ['La Rochelle', 'Rémi BOURDEAU', '3ème ligne', '27/02/1992', '195', '108']
# ['La Rochelle', 'Victor VITO', '3ème ligne', '27/03/1987', '192', '112']
# ['La Rochelle', 'Wiaan LIEBENBERG', '3ème ligne', '31/08/1992', '189', '105']
# ['La Rochelle', 'Zeno KIEFT', '3ème ligne', '02/11/1991', '191', '102']
# ['La Rochelle', 'Alexi BALÈS', 'Demi', '30/05/1990', '174', '80']
# ['La Rochelle', 'Tawera KERR-BARLOW', 'Demi', '15/08/1990', '187', '91']
# ['La Rochelle', 'Brock JAMES', 'Demi', '22/10/1981', '179', '89']
# ['La Rochelle', 'Ihaia WEST', 'Demi', '16/01/1992', '175', '85']
# ['La Rochelle', 'Maxime LAFAGE', 'Demi', '01/09/1994', '183', '84']
# ['La Rochelle', 'Brieuc PLESSIS-COUILLAUD', 'Trois-Quarts', '19/03/1994', '180', '95']
# ['La Rochelle', 'Geoffrey DOUMAYROU', 'Trois-Quarts', '16/09/1989', '186', '92']
# ['La Rochelle', 'Jérémy SINZELLE', 'Trois-Quarts', '02/07/1990', '184', '88']
# ['La Rochelle', 'Jules FAVRE', 'Trois-Quarts', '22/03/1999', '181', '88']
# ['La Rochelle', 'Levani BOTIA', 'Trois-Quarts', '14/03/1989', '182', '103']
# ['La Rochelle', 'Pierre AGUILLON', 'Trois-Quarts', '27/03/1987', '180', '93']
# ['La Rochelle', 'Arthur RETIÈRE', 'Trois-Quarts', '01/08/1997', '173', '75']
# ['La Rochelle', 'Eliott ROUDIL', 'Trois-Quarts', '30/10/1996', '184', '97']
# ['La Rochelle', 'Gabriel LACROIX', 'Trois-Quarts', '19/10/1993', '171', '80']
# ['La Rochelle', 'Marc ANDREU', 'Trois-Quarts', '27/12/1985', '170', '75']
# ['La Rochelle', 'Kini MURIMURIVALU', 'Arrière', '15/05/1989', '176', '97']
# ['La Rochelle', 'Vincent RATTEZ', 'Arrière', '24/03/1992', '180', '78']
# ['Lyon', 'Clément RIC', 'Avant', '18/07/1988', '182', '117']
# ['Lyon', 'Francisco GOMEZ KODELA', 'Avant', '03/07/1985', '184', '121']
# ['Lyon', 'Hamza KAABÈCHE', 'Avant', '23/09/1996', '188', '118']
# ['Lyon', 'Raphaël CHAUME', 'Avant', '29/04/1989', '185', '110']
# ['Lyon', 'Vivien DEVISME', 'Avant', '23/03/1992', '175', '112']
# ['Lyon', 'Xavier CHIOCCI', 'Avant', '13/02/1990', '180', '110']
# ['Lyon', 'Badri ALKHAZASHVILI', 'Avant', '31/07/1995', '185', '110']
# ['Lyon', 'Jérémie MAUROUARD', 'Avant', '23/09/1992', '181', '100']
# ['Lyon', 'Mickaël IVALDI', 'Avant', '20/02/1990', '181', '108']
# ['Lyon', 'Etienne OOSTHUIZEN', '2ème ligne', '22/12/1992', '198', '120']
# ['Lyon', 'Félix LAMBEY', '2ème ligne', '15/03/1994', '196', '110']
# ['Lyon', 'Hendrik ROODT', '2ème ligne', '06/11/1987', '198', '126']
# ['Lyon', 'Kilian GÉRACI', '2ème ligne', '25/03/1999', '200', '106']
# ['Lyon', 'Virgile BRUNI', '2ème ligne', '06/02/1989', '198', '109']
# ['Lyon', 'Carl FEARNS', '3ème ligne', '28/05/1989', '191', '118']
# ['Lyon', 'Dylan CRETIN', '3ème ligne', '04/05/1997', '195', '101']
# ['Lyon', 'Julien PURICELLI', '3ème ligne', '01/08/1981', '196', '103']
# ['Lyon', 'Liam GILL', '3ème ligne', '08/06/1992', '184', '100']
# ['Lyon', 'Loann GOUJON', '3ème ligne', '23/04/1989', '194', '106']
# ['Lyon', 'Patrick SOBELA', '3ème ligne', '12/08/1992', '188', '105']
# ['Lyon', 'Tanginoa HALAIFONUA', '3ème ligne', '03/08/1996', '196', '114']
# ['Lyon', 'Baptiste COUILLOUD', 'Demi', '22/07/1997', '176', '77']
# ['Lyon', 'Jonathan PÉLISSIÉ', 'Demi', '06/06/1988', '179', '83']
# ['Lyon', 'Jean-Marc DOUSSAIN', 'Demi', '12/02/1991', '174', '88']
# ['Lyon', 'Jonathan WISNIEWSKI', 'Demi', '16/07/1985', '180', '85']
# ['Lyon', 'Patricio FERNANDEZ', 'Demi', '11/10/1994', '192', '100']
# ['Lyon', 'Charlie NGATAI', 'Trois-Quarts', '17/08/1990', '188', '103']
# ['Lyon', 'Mathieu BASTAREAUD', 'Trois-Quarts', '17/09/1988', '183', '123']
# ['Lyon', 'Pierre-Louis BARASSI', 'Trois-Quarts', '22/04/1998', '188', '93']
# ['Lyon', 'Rudi WULF', 'Trois-Quarts', '02/02/1984', '182', '90']
# ['Lyon', 'Thibaut REGARD', 'Trois-Quarts', '06/08/1993', '180', '95']
# ['Lyon', 'Alexis PALISSON', 'Trois-Quarts', '09/09/1987', '177', '85']
# ['Lyon', 'Josua TUISOVA', 'Trois-Quarts', '04/02/1994', '180', '91']
# ['Lyon', 'Noa NAKAITACI', 'Trois-Quarts', '11/07/1990', '190', '94']
# ['Lyon', 'Toby ARNOLD', 'Trois-Quarts', '11/09/1987', '178', '86']
# ['Lyon', 'Xavier MIGNOT', 'Trois-Quarts', '27/01/1994', '188', '100']
# ['Lyon', 'Clément LAPORTE', 'Arrière', '07/01/1998', '181', '87']
# ['Lyon', 'Jean-Marcellin BUTTIN', 'Arrière', '16/12/1991', '190', '94']
# ['Montpellier', 'Antoine GUILLAMON', 'Avant', '04/06/1991', '192', '136']
# ['Montpellier', 'Daniel BRENNAN', 'Avant', '23/09/1998', '192', '132']
# ['Montpellier', 'Grégory FICHTEN', 'Avant', '13/08/1990', '183', '124']
# ['Montpellier', 'Jannie DU PLESSIS', 'Avant', '16/11/1982', '188', '121']
# ['Montpellier', 'Levan CHILACHAVA', 'Avant', '17/08/1991', '188', '118']
# ['Montpellier', 'Lizo GQOBOKA', 'Avant', '24/03/1990', '183', '118']
# ['Montpellier', 'Luka AZARIASHVILI', 'Avant', '30/11/1999', '186', '118']
# ['Montpellier', 'Misha NARIASHVILI', 'Avant', '25/05/1990', '186', '118']
# ['Montpellier', 'Mohamed HAOUAS', 'Avant', '09/03/1994', '185', '127']
# ['Montpellier', 'Bismarck DU PLESSIS', 'Avant', '22/05/1984', '189', '114']
# ['Montpellier', 'Guilhem GUIRADO', 'Avant', '17/06/1986', '183', '105']
# ['Montpellier', 'Ronan CHAMBORD', 'Avant', '11/04/1994', '177', '104']
# ['Montpellier', 'Valentin SEILLÉ', 'Avant', '07/04/1999', '182', '108']
# ['Montpellier', 'Vincent GIUDICELLI', 'Avant', '25/06/1997', '183', '100']
# ['Montpellier', 'Youri DELHOMMEL', 'Avant', '06/03/1996', '181', '100']
# ['Montpellier', 'Jacques DU PLESSIS', '2ème ligne', '12/08/1993', '201', '123']
# ['Montpellier', 'Julien LEDEVEDEC', '2ème ligne', '04/06/1986', '199', '114']
# ['Montpellier', 'Konstantine MIKAUTADZE', '2ème ligne', '01/07/1991', '200', '128']
# ['Montpellier', 'Nicolaas Janse VAN RENSBURG', '2ème ligne', '06/05/1994', '200', '112']
# ['Montpellier', 'Paul WILLEMSE', '2ème ligne', '13/11/1992', '201', '129']
# ['Montpellier', 'Caleb TIMU', '3ème ligne', '22/02/1994', '190', '117']
# ['Montpellier', 'Fulgence OUEDRAOGO', '3ème ligne', '21/07/1986', '191', '99']
# ['Montpellier', 'Julien BARDY', '3ème ligne', '03/04/1986', '188', '98']
# ['Montpellier', 'Kélian GALLETIER', '3ème ligne', '18/03/1992', '188', '100']
# ['Montpellier', 'Kévin KORNATH', '3ème ligne', '27/12/1996', '194', '110']
# ['Montpellier', 'Louis PICAMOLES', '3ème ligne', '05/02/1986', '192', '118']
# ['Montpellier', 'Lucas DE CONINCK', '3ème ligne', '15/01/1996', '194', '110']
# ['Montpellier', 'Martin DEVERGIE', '3ème ligne', '26/06/1995', '193', '116']
# ['Montpellier', 'Yacouba CAMARA', '3ème ligne', '02/06/1994', '195', '112']
# ['Montpellier', 'Benoît PAILLAUGUE', 'Demi', '17/11/1987', '172', '74']
# ['Montpellier', 'Enzo SANGA', 'Demi', '19/05/1995', '176', '75']
# ['Montpellier', "Kahn FOTUALI'I", 'Demi', '22/05/1982', '183', '96']
# ['Montpellier', 'Aaron CRUDEN', 'Demi', '08/01/1989', '178', '84']
# ['Montpellier', 'Handré POLLARD', 'Demi', '11/03/1994', '189', '98']
# ['Montpellier', 'Thomas DARMON', 'Demi', '12/05/1998', '181', '83']
# ['Montpellier', 'Arthur VINCENT', 'Trois-Quarts', '30/09/1999', '183', '90']
# ['Montpellier', 'François STEYN', 'Trois-Quarts', '14/05/1987', '191', '111']
# ['Montpellier', 'Jan SERFONTEIN', 'Trois-Quarts', '15/04/1993', '187', '97']
# ['Montpellier', 'Vincent MARTIN', 'Trois-Quarts', '04/09/1992', '185', '93']
# ['Montpellier', 'Yvan REILHAC', 'Trois-Quarts', '09/06/1995', '182', '92']
# ['Montpellier', "Gabriel N'GANDEBE", 'Trois-Quarts', '30/03/1997', '174', '75']
# ['Montpellier', 'Nemani NADOLO', 'Trois-Quarts', '31/01/1988', '194', '130']
# ['Montpellier', 'Pierre TOURNEBIZE', 'Trois-Quarts', '25/09/1998', '186', '98']
# ['Montpellier', 'Timoci NAGUSA', 'Trois-Quarts', '14/07/1987', '183', '106']
# ['Montpellier', 'Anthony BOUTHIER', 'Arrière', '19/06/1992', '182', '86']
# ['Montpellier', 'Benjamin FALL', 'Arrière', '03/03/1989', '186', '93']
# ['Montpellier', 'Henry IMMELMAN', 'Arrière', '26/05/1995', '189', '96']
# ['Montpellier', 'Johan GOOSEN', 'Arrière', '27/07/1992', '184', '89']
# ['Paris', 'Carlü SADIE', 'Avant', '07/03/1997', '180', '124']
# ['Paris', 'Christopher VAOTOA', 'Avant', '16/11/1996', '185', '138']
# ['Paris', 'Giorgi MELIKIDZE', 'Avant', '24/05/1996', '179', '117']
# ['Paris', 'Luke TAGI', 'Avant', '23/06/1997', '187', '130']
# ['Paris', 'Paul ALO-EMILE', 'Avant', '22/12/1991', '180', '128']
# ['Paris', 'Quentin BÉTHUNE', 'Avant', '25/09/1995', '183', '112']
# ['Paris', 'Sami MAVINGA', 'Avant', '25/05/1993', '181', '116']
# ['Paris', 'Stéphane CLÉMENT', 'Avant', '03/09/1987', '183', '121']
# ['Paris', 'Thierry FUTEU', 'Avant', '23/06/1995', '186', '114']
# ['Paris', 'Damien FITZPATRICK', 'Avant', '08/06/1989', '183', '105']
# ['Paris', 'Laurent PANIS', 'Avant', '23/04/1993', '180', '102']
# ['Paris', 'Lucas DA SILVA', 'Avant', '19/12/1997', '188', '115']
# ['Paris', 'Rémi BONFILS', 'Avant', '26/09/1988', '178', '101']
# ['Paris', "Sione ANGA'AELANGI", 'Avant', '07/11/1988', '180', '106']
# ['Paris', 'Tolu LATU', 'Avant', '23/02/1993', '180', '113']
# ['Paris', 'Hugh PYLE', '2ème ligne', '21/09/1988', '201', '116']
# ['Paris', 'Mathieu DE GIOVANNI', '2ème ligne', '10/01/1994', '197', '115']
# ['Paris', 'Paul GABRILLAGUES', '2ème ligne', '03/06/1993', '199', '119']
# ['Paris', 'Pierre-Henri AZAGOH', '2ème ligne', '25/07/1998', '198', '105']
# ['Paris', 'Yoann MAESTRI', '2ème ligne', '14/01/1988', '202', '119']
# ['Paris', 'Antoine BURBAN', '3ème ligne', '22/07/1987', '189', '101']
# ['Paris', 'Charlie FRANCOZ', '3ème ligne', '03/06/1998', '195', '108']
# ['Paris', 'Joketani KOROI', '3ème ligne', '01/01/1996', '198', '115']
# ['Paris', 'Josh STRAUSS', '3ème ligne', '23/10/1986', '200', '114']
# ['Paris', 'Loïc GODENER', '3ème ligne', '13/08/1995', '188', '115']
# ['Paris', 'Pablo MATERA', '3ème ligne', '18/07/1993', '193', '110']
# ['Paris', 'Ryan CHAPUIS', '3ème ligne', '12/12/1997', '189', '104']
# ['Paris', 'Sekou MACALOU', '3ème ligne', '20/04/1995', '195', '100']
# ['Paris', 'Talalelei GRAY', '3ème ligne', '28/02/1990', '194', '110']
# ['Paris', 'Willem ALBERTS', '3ème ligne', '11/05/1984', '192', '120']
# ['Paris', 'Arthur COVILLE', 'Demi', '04/02/1998', '178', '83']
# ['Paris', 'Clément DAGUIN', 'Demi', '25/05/1992', '180', '87']
# ['Paris', 'James HALL', 'Demi', '02/01/1996', '172', '84']
# ['Paris', 'Joris SEGONDS', 'Demi', '06/04/1997', '180', '91']
# ['Paris', 'Jules PLISSON', 'Demi', '20/08/1991', '184', '88']
# ['Paris', 'Morné STEYN', 'Demi', '11/07/1984', '183', '91']
# ['Paris', 'Nicolas SANCHEZ', 'Demi', '26/10/1988', '177', '85']
# ['Paris', 'Alex ARRATE', 'Trois-Quarts', '24/06/1997', '180', '90']
# ['Paris', 'Gaël FICKOU', 'Trois-Quarts', '26/03/1994', '190', '100']
# ['Paris', 'Jonathan DANTY', 'Trois-Quarts', '07/10/1992', '181', '107']
# ['Paris', 'Julien DELBOUIS', 'Trois-Quarts', '04/08/1999', '185', '95']
# ['Paris', 'Lionel MAPOE', 'Trois-Quarts', '13/07/1988', '183', '95']
# ['Paris', 'Adrien LAPÈGUE', 'Trois-Quarts', '21/10/1998', '181', '88']
# ['Paris', 'Julien ARIAS', 'Trois-Quarts', '26/10/1983', '178', '89']
# ['Paris', 'Lester ETIEN', 'Trois-Quarts', '21/06/1995', '180', '90']
# ['Paris', 'Ruan COMBRINCK', 'Trois-Quarts', '10/05/1990', '183', '97']
# ['Paris', 'Sefa NAIVALU', 'Trois-Quarts', '07/01/1992', '186', '101']
# ['Paris', 'Waisea NAYACALEVU', 'Trois-Quarts', '26/06/1990', '193', '104']
# ['Paris', 'Kylan HAMDAOUI', 'Arrière', '15/04/1994', '182', '84']
# ['Pau', 'Geoffrey MOÏSE', 'Avant', '20/08/1991', '187', '130']
# ['Pau', 'Ignacio CALLES', 'Avant', '24/10/1995', '187', '116']
# ['Pau', 'Lourens ADRIAANSE', 'Avant', '05/02/1988', '181', '115']
# ['Pau', 'Lucas POINTUD', 'Avant', '18/01/1988', '189', '127']
# ['Pau', 'Malik HAMADACHE', 'Avant', '17/10/1988', '193', '141']
# ['Pau', 'Mohamed BOUGHANMI', 'Avant', '27/10/1991', '194', '126']
# ['Pau', 'Nicolas CORATO', 'Avant', '07/10/1997', '184', '120']
# ['Pau', "Siegfried FISI'IHOI", 'Avant', '06/08/1987', '184', '125']
# ['Pau', 'Lucas REY', 'Avant', '27/04/1997', '175', '95']
# ['Pau', 'Quentin LESPIAUCQ-BRETTES', 'Avant', '16/02/1995', '180', '95']
# ['Pau', 'Dan MALAFOSSE', '2ème ligne', '14/01/1992', '195', '121']
# ['Pau', 'Daniel RAMSAY', '2ème ligne', '01/06/1984', '197', '114']
# ['Pau', 'Denis MARCHOIS', '2ème ligne', '05/02/1994', '198', '115']
# ['Pau', 'Fabrice METZ', '2ème ligne', '23/01/1991', '196', '121']
# ['Pau', 'Julien DELANNOY', '2ème ligne', '15/06/1995', '198', '123']
# ['Pau', 'Antoine ERBANI', '3ème ligne', '07/02/1990', '192', '100']
# ['Pau', 'Baptiste PESENTI', '3ème ligne', '03/07/1997', '195', '118']
# ['Pau', 'Clément FOURNIER', '3ème ligne', '06/05/2000', '190', '105']
# ['Pau', 'Dominiko WAQANIBUROTU', '3ème ligne', '20/04/1986', '193', '114']
# ['Pau', 'Giovanni HABEL-KUEFFNER', '3ème ligne', '09/01/1995', '190', '110']
# ['Pau', 'Lekima TAGITAGIVALU', '3ème ligne', '12/12/1995', '193', '109']
# ['Pau', 'Luke WHITELOCK', '3ème ligne', '29/01/1991', '190', '116']
# ['Pau', 'Martin PUECH', '3ème ligne', '14/12/1988', '193', '95']
# ['Pau', 'Matthieu UGENA', '3ème ligne', '25/07/1995', '186', '106']
# ['Pau', 'Pierrick GUNTHER', '3ème ligne', '16/10/1989', '190', '106']
# ['Pau', 'Clovis LE BAIL', 'Demi', '29/11/1995', '173', '74']
# ['Pau', 'Samuel MARQUÈS', 'Demi', '08/12/1988', '177', '76']
# ['Pau', 'Thibault DAUBAGNA', 'Demi', '20/05/1994', '177', '80']
# ['Pau', 'Antoine HASTOY', 'Demi', '04/06/1997', '180', '86']
# ['Pau', 'Colin SLADE', 'Demi', '10/10/1987', '183', '90']
# ['Pau', 'Tom TAYLOR', 'Demi', '11/03/1989', '183', '90']
# ['Pau', 'Alexandre DUMOULIN', 'Trois-Quarts', '24/08/1989', '189', '101']
# ['Pau', 'Atila SEPTAR', 'Trois-Quarts', '02/06/1996', '195', '99']
# ['Pau', 'Benson STANLEY', 'Trois-Quarts', '11/09/1984', '184', '98']
# ['Pau', 'Florian NICOT', 'Trois-Quarts', '30/09/1986', '184', '95']
# ['Pau', 'Jale VATUBUA', 'Trois-Quarts', '30/08/1991', '189', '121']
# ['Pau', 'Julien FUMAT', 'Trois-Quarts', '26/03/1987', '180', '83']
# ['Pau', 'Pierre NUENO', 'Trois-Quarts', '15/05/1996', '184', '90']
# ['Pau', 'Bastien POURAILLY', 'Trois-Quarts', '31/01/1994', '177', '80']
# ['Pau', 'Ben SMITH', 'Trois-Quarts', '01/06/1986', '186', '94']
# ['Pau', 'Vincent PINTO', 'Trois-Quarts', '10/04/1999', '187', '93']
# ['Pau', 'Watisoni VOTU', 'Trois-Quarts', '25/03/1985', '187', '100']
# ['Pau', 'Charly MALIÉ', 'Arrière', '05/11/1991', '185', '87']
# ['Pau', 'Jesse MOGG', 'Arrière', '08/06/1989', '187', '90']
# ['Racing92', 'Ali OZ', 'Avant', '28/05/1995', '193', '140']
# ['Racing92', 'Ben TAMEIFUNA', 'Avant', '30/08/1991', '182', '140']
# ['Racing92', 'Cedate GOMES SA', 'Avant', '07/08/1993', '185', '113']
# ['Racing92', 'Eddy BEN AROUS', 'Avant', '25/08/1990', '183', '117']
# ['Racing92', 'Georges-Henri COLOMBE', 'Avant', '09/04/1998', '193', '133']
# ['Racing92', 'Hassane KOLINGAR', 'Avant', '06/03/1998', '186', '116']
# ['Racing92', 'Vasil KAKOVIN', 'Avant', '01/12/1989', '183', '110']
# ['Racing92', 'Camille CHAT', 'Avant', '18/12/1995', '178', '101']
# ['Racing92', 'Issam HAMEL', 'Avant', '18/06/1997', '180', '110']
# ['Racing92', 'Kévin LE GUEN', 'Avant', '17/11/1990', '183', '105']
# ['Racing92', 'Teddy BAUBIGNY', 'Avant', '02/09/1998', '187', '111']
# ['Racing92', 'Dominic BIRD', '2ème ligne', '09/04/1991', '206', '115']
# ['Racing92', 'Donnacha RYAN', '2ème ligne', '11/12/1983', '201', '114']
# ['Racing92', 'Leone NAKARAWA', '2ème ligne', '04/02/1988', '200', '125']
# ['Racing92', 'Antonie CLAASSEN', '3ème ligne', '20/10/1984', '191', '106']
# ['Racing92', 'Baptiste CHOUZENOUX', '3ème ligne', '07/08/1993', '202', '107']
# ['Racing92', 'Bernard LE ROUX', '3ème ligne', '04/06/1989', '196', '113']
# ['Racing92', 'Boris PALU', '3ème ligne', '04/02/1996', '193', '109']
# ['Racing92', 'Fabien SANCONNIE', '3ème ligne', '21/02/1995', '195', '110']
# ['Racing92', 'Ibrahim DIALLO', '3ème ligne', '23/01/1998', '193', '109']
# ['Racing92', 'Jordan JOSEPH', '3ème ligne', '31/07/2000', '189', '115']
# ['Racing92', 'Wenceslas LAURET', '3ème ligne', '28/03/1989', '188', '103']
# ['Racing92', 'Yoan TANGA-MANGENE', '3ème ligne', '29/11/1996', '185', '108']
# ['Racing92', 'Antoine GIBERT', 'Demi', '31/12/1997', '177', '76']
# ['Racing92', 'Maxime MACHENAUD', 'Demi', '30/12/1988', '174', '87']
# ['Racing92', 'Sam HIDALGO-CLYNE', 'Demi', '04/08/1993', '175', '76']
# ['Racing92', 'Teddy IRIBAREN', 'Demi', '25/09/1990', '170', '70']
# ['Racing92', 'Ben VOLAVOLA', 'Demi', '13/01/1991', '191', '93']
# ['Racing92', 'Finn RUSSELL', 'Demi', '23/09/1992', '183', '87']
# ['Racing92', 'François TRINH-DUC', 'Demi', '11/11/1986', '186', '90']
# ['Racing92', 'Joaquin DIAZ BONILLA', 'Demi', '12/04/1989', '177', '80']
# ['Racing92', 'Henry CHAVANCY', 'Trois-Quarts', '22/05/1988', '181', '92']
# ['Racing92', 'Léonard PARIS', 'Trois-Quarts', '20/03/1996', '180', '92']
# ['Racing92', 'Olivier KLEMENCZAK', 'Trois-Quarts', '01/06/1996', '181', '81']
# ['Racing92', 'Virimi VAKATAWA', 'Trois-Quarts', '01/05/1992', '185', '98']
# ['Racing92', 'Dorian LABORDE', 'Trois-Quarts', '30/12/1996', '178', '107']
# ['Racing92', 'Juan IMHOFF', 'Trois-Quarts', '11/05/1988', '185', '90']
# ['Racing92', 'Simon ZEBO', 'Trois-Quarts', '16/03/1990', '187', '94']
# ['Racing92', 'Teddy THOMAS', 'Trois-Quarts', '18/09/1993', '185', '90']
# ['Racing92', 'Brice DULIN', 'Arrière', '13/04/1990', '176', '82']
# ['Racing92', 'Louis DUPICHOT', 'Arrière', '23/09/1995', '183', '86']
# ['Toulon', 'Beka GIGASHVILI', 'Avant', '17/02/1992', '177', '114']
# ['Toulon', 'Bruce DEVAUX', 'Avant', '14/11/1996', '183', '108']
# ['Toulon', 'Florian FRESIA', 'Avant', '17/01/1992', '185', '110']
# ['Toulon', 'Jean-Baptiste GROS', 'Avant', '29/05/1999', '187', '110']
# ['Toulon', 'Marcel VAN DER MERWE', 'Avant', '24/10/1990', '188', '120']
# ['Toulon', 'Sébastien TAOFIFENUA', 'Avant', '21/03/1992', '178', '130']
# ['Toulon', 'Wilco LOUW', 'Avant', '20/07/1994', '185', '133']
# ['Toulon', 'Anthony ÉTRILLARD', 'Avant', '21/03/1993', '183', '110']
# ['Toulon', 'Bastien SOURY', 'Avant', '18/03/1995', '180', '105']
# ['Toulon', 'Christopher TOLOFUA', 'Avant', '31/12/1993', '182', '117']
# ['Toulon', "Brian ALAINU'UESE", '2ème ligne', '19/03/1994', '202', '135']
# ['Toulon', 'Corentin VERNET', '2ème ligne', '27/09/1996', '200', '127']
# ['Toulon', 'Eben ETZEBETH', '2ème ligne', '29/10/1991', '203', '117']
# ['Toulon', 'Mamuka GORGODZE', '2ème ligne', '14/07/1984', '196', '120']
# ['Toulon', 'Romain TAOFIFENUA', '2ème ligne', '14/09/1990', '200', '127']
# ['Toulon', 'Swan REBBADJ', '2ème ligne', '15/01/1995', '202', '116']
# ['Toulon', 'Charles OLLIVON', '3ème ligne', '11/05/1993', '199', '114']
# ['Toulon', 'Facundo ISA', '3ème ligne', '21/09/1993', '188', '111']
# ['Toulon', 'Liam MESSAM', '3ème ligne', '25/03/1984', '190', '109']
# ['Toulon', 'Raphaël LAKAFIA', '3ème ligne', '28/10/1988', '191', '115']
# ['Toulon', 'Sergio PARISSE', '3ème ligne', '12/09/1983', '196', '122']
# ['Toulon', 'Stéphane ONAMBÉLÉ', '3ème ligne', '12/02/1993', '188', '94']
# ['Toulon', 'Thomas HOARAU', '3ème ligne', '01/06/1995', '190', '112']
# ['Toulon', 'Anthony MÉRIC', 'Demi', '15/02/1995', '177', '77']
# ['Toulon', 'Baptiste SERIN', 'Demi', '20/06/1994', '180', '79']
# ['Toulon', 'Louis SCHREUDER', 'Demi', '25/04/1990', '184', '82']
# ['Toulon', 'Rhys WEBB', 'Demi', '09/12/1988', '183', '93']
# ['Toulon', 'Anthony BELLEAU', 'Demi', '08/04/1996', '177', '85']
# ['Toulon', 'Louis CARBONEL', 'Demi', '04/02/1999', '180', '85']
# ['Toulon', 'Mathieu SMAÏLI', 'Demi', '30/08/1999', '180', '84']
# ['Toulon', "Ben TE'O", 'Trois-Quarts', '27/01/1987', '188', '105']
# ['Toulon', "Duncan PAIA'AUA", 'Trois-Quarts', '20/01/1995', '180', '91']
# ['Toulon', 'Julian SAVEA', 'Trois-Quarts', '07/08/1990', '192', '108']
# ['Toulon', 'Julien HÉRITEAU', 'Trois-Quarts', '12/09/1994', '181', '90']
# ['Toulon', 'Théo DACHARY', 'Trois-Quarts', '26/03/1997', '184', '92']
# ['Toulon', 'Bryce HEEM ', 'Trois-Quarts', '18/01/1989', '193', '105']
# ['Toulon', 'Daniel IKPEFAN', 'Trois-Quarts', '18/10/1993', '185', '92']
# ['Toulon', 'Gabin VILLIÈRE', 'Trois-Quarts', '13/12/1995', '180', '87']
# ['Toulon', 'Masivesi DAKUWAQA', 'Trois-Quarts', '14/02/1994', '190', '105']
# ['Toulon', 'Gervais CORDIN', 'Arrière', '10/12/1998', '172', '73']
# ['Toulon', 'Hugo BONNEVAL', 'Arrière', '19/11/1990', '185', '90']
# ['Toulon', 'Nehe MILNER-SKUDDER', 'Arrière', '15/12/1990', '182', '90']
# ['Toulouse', 'Charlie FAUMUINA', 'Avant', '24/12/1986', '184', '128']
# ['Toulouse', 'Clément CASTETS', 'Avant', '05/05/1996', '183', '110']
# ['Toulouse', 'Cyril BAILLE', 'Avant', '15/09/1993', '182', '116']
# ['Toulouse', 'Dorian ALDEGHERI', 'Avant', '04/08/1993', '180', '119']
# ['Toulouse', 'Maks VAN DYK', 'Avant', '21/01/1992', '186', '118']
# ['Toulouse', 'Paulo TAFILI', 'Avant', '15/02/1996', '183', '132']
# ['Toulouse', 'Rémy HUGUES', 'Avant', '01/01/1986', '183', '114']
# ['Toulouse', 'Rodrigue NETI', 'Avant', '26/04/1995', '185', '124']
# ['Toulouse', 'Guillaume CRAMONT', 'Avant', '29/12/2000', '182', '97']
# ['Toulouse', 'Guillaume MARCHAND', 'Avant', '05/06/1998', '183', '100']
# ['Toulouse', 'Jaco VISAGIE', 'Avant', '08/07/1992', '188', '105']
# ['Toulouse', 'Julien MARCHAND', 'Avant', '10/05/1995', '181', '95']
# ['Toulouse', 'Takeshi HINO', 'Avant', '20/01/1990', '172', '100']
# ['Toulouse', 'Bastien CHALUREAU', '2ème ligne', '13/02/1992', '202', '121']
# ['Toulouse', 'Florian VERHAEGHE', '2ème ligne', '27/04/1997', '202', '108']
# ['Toulouse', 'Iosefa TEKORI', '2ème ligne', '17/12/1983', '198', '127']
# ['Toulouse', 'Richie ARNOLD', '2ème ligne', '01/07/1990', '208', '127']
# ['Toulouse', 'Richie GRAY', '2ème ligne', '24/08/1989', '206', '125']
# ['Toulouse', 'Rory ARNOLD', '2ème ligne', '01/07/1990', '208', '120']
# ['Toulouse', 'Alban PLACINES', '3ème ligne', '23/04/1993', '189', '110']
# ['Toulouse', 'Antoine MIQUEL', '3ème ligne', '20/06/1994', '192', '109']
# ['Toulouse', 'Carl AXTENS', '3ème ligne', '26/08/1991', '193', '117']
# ['Toulouse', 'François CROS', '3ème ligne', '25/03/1994', '190', '95']
# ['Toulouse', 'Gillian GALAN', '3ème ligne', '07/08/1991', '193', '120']
# ['Toulouse', 'Jerome KAINO', '3ème ligne', '06/04/1983', '196', '113']
# ['Toulouse', 'Louis-Benoît MADAULE', '3ème ligne', '24/09/1988', '190', '104']
# ['Toulouse', 'Rynhardt ELSTADT', '3ème ligne', '20/12/1989', '198', '120']
# ['Toulouse', 'Selevasio TOLOFUA', '3ème ligne', '31/05/1997', '186', '115']
# ['Toulouse', 'Antoine DUPONT', 'Demi', '15/11/1996', '174', '82']
# ['Toulouse', 'Pierre PAGÈS', 'Demi', '16/05/1990', '180', '78']
# ['Toulouse', 'Sébastien BÉZY', 'Demi', '22/11/1991', '174', '74']
# ['Toulouse', 'Romain NTAMACK', 'Demi', '01/05/1999', '186', '84']
# ['Toulouse', 'Tristan TEDDER', 'Demi', '17/04/1996', '180', '80']
# ['Toulouse', 'Zack HOLMES', 'Demi', '30/05/1990', '175', '90']
# ['Toulouse', 'Maxime MERMOZ', 'Trois-Quarts', '28/07/1986', '181', '93']
# ['Toulouse', 'Pierre FOUYSSAC', 'Trois-Quarts', '17/03/1995', '190', '100']
# ['Toulouse', 'Pita AHKI', 'Trois-Quarts', '24/09/1992', '189', '97']
# ['Toulouse', 'Théo BELAN', 'Trois-Quarts', '15/11/1992', '187', '94']
# ['Toulouse', 'Arthur BONNEVAL', 'Trois-Quarts', '31/05/1995', '181', '82']
# ['Toulouse', 'Cheslin KOLBE', 'Trois-Quarts', '28/10/1993', '171', '80']
# ['Toulouse', 'Lucas TAUZIN', 'Trois-Quarts', '21/05/1998', '187', '98']
# ['Toulouse', 'Sofiane GUITOUNE', 'Trois-Quarts', '27/03/1989', '186', '96']
# ['Toulouse', 'Werner KOK', 'Trois-Quarts', '27/01/1993', '177', '78']
# ['Toulouse', 'Yoann HUGET', 'Trois-Quarts', '02/06/1987', '190', '97']
# ['Toulouse', 'Matthis LEBEL', 'Arrière', '25/03/1999', '185', '91']
# ['Toulouse', 'Maxime MÉDARD', 'Arrière', '16/11/1986', '180', '85']
# ['Toulouse', 'Thomas RAMOS', 'Arrière', '23/07/1995', '178', '86']

# %% [markdown]
# ##  Observation des postes des joueurs sur un graphique

# %% [markdown]
# Compléter le code de la fonction <code>extraireEquipe(donnees,equipe)</code> qui extrait les données d'une équipe passée en paramètre.
# ```

# %%
def extraireEquipe(donnees,nom_equipe):
    return [donnee for donnee in donnees if donnee[0] == nom_equipe]

# %% [markdown]
# La fonction <code>representation(nom_equipe,donnees)</code> permet de représenter graphiquement les postes des joeeurs avec un nuage de points les données d'une équipe passée en paramètre avec sur l'axe des abscisses la taille des joueurs et sur l'axe des ordonnées le poids des joueurs.

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
from random import shuffle

def representation(nom_equipe,donnees):
    plt.axis([170, 210, 70, 140])
    plt.ylabel("Poids")
    plt.xlabel("Taille")
    plt.title(nom_equipe)
    labels = []
    for donnee in donnees:
        if donnee[2] == "Avant":
            marque = "bx"
        elif donnee[2] == "2ème ligne":
            marque = "*r"
        elif donnee[2] == "3ème ligne":
            marque = "*g"
        elif donnee[2] == "Demi":
            marque = "^r"
        elif donnee[2] == "Trois-Quarts":
            marque = "*m"
        elif donnee[2] == "Arrière":
            marque = "^b"
        else:
            marque = "^b"
        if donnee[2] in labels:
            plt.plot(int(donnee[4]), int(donnee[5]), marque)
        else:
            labels.append(donnee[2])
            plt.plot(int(donnee[4]), int(donnee[5]), marque,label = donnee[2])
    plt.legend()
    plt.show()


donnees_equipe = extraireEquipe(donnees,"Toulouse")

representation("Toulouse",donnees_equipe)

# %% [markdown]
# ## Séparation des données pour le test et pour l'entrainement
# On divise les donnees en deux parties :
#
#
# *   une pour l'entrainement (80%)
# *   une autre pour les tests (20%)

# %%
nb_entrainements = int(len(donnees) * 0.85)
shuffle(donnees)
donnees_entrainement = donnees[:nb_entrainements]
donnees_test = donnees[nb_entrainements:]

# %% [markdown]
# ## Implémentation de la fonction distance
#
# On mesure la distance Euclidienne entre deux joueurs avec la fonction <code>def distance(j1, j2)</code>.
# avec :
#
# *   <code>j1 = (t1,p1)</code> t1 : taille en cm et p1 poids en kg du joueur 1
# *   <code>j2 = (t2,p2)</code> t2 : taille en cm et p2 poids en kg du joueur 1
#
#
# Complétez le code de cette fonction.

# %%
from math import sqrt


def distance(j1,j2):
    pass
    return sqrt((int(j1[0]) - int(j2[0]))**2 + (int(j1[1]) - int(j2[1]))**2)

# %% [markdown]
# ## Algorithme du plus proche voisin
# On commence par écrire une fonction <code>plus_proche(i)</code>qui recherche dans les données d’entrainement le joueur le plus proche du joueur de test d’indice i.
# Complétez le code de cette fonction.

# %%
# def plus_proche(i):
#     "Renvoie le poste du plus proche voisin dans train du joueur de test d'indice i"
#     joueur_test = donnees_test[i]
#     # on initialise l'indice et la distance minimum sur
#     # la première donnée d'entraînement
#     j_min = 0
#     d_min = distance((joueur_test[5],joueur_test[6]),(donnees_entrainement[0][5],donnees_entrainement[0][6]))
#     # on recherche le joueur avec la distance minimum
#     # dans les données d'entrainement
#     for j in range(len(train)):
#          d = distance((joueur_test[5],joueur_test[6]),(donnees_entrainement[j][5],donnees_entrainement[j][6]))
#         ...

#     return ...

def plus_proche(i):
    joueur_test = donnees_test[i]
    j_min = 0
    d_min = distance((joueur_test[4],joueur_test[5]),(donnees_entrainement[0][4],donnees_entrainement[0][5]))
    for j in range(len(donnees_entrainement)):
        d = distance((joueur_test[4],joueur_test[5]),(donnees_entrainement[j][4],donnees_entrainement[j][5]))
        if d < d_min:
            d_min = d
            j_min = j
    return donnees_entrainement[j_min]

# %% [markdown]
# ## Calcul du taux d’erreur
# Puisque l’algorithme commet des erreurs regardons combien il en fait et quel pourcentage cela représente.

# %%
# def taux_erreur():
#     erreur = 0
#     for i in range(len(donnees_test)):
#         ...
#         if poste_predit != poste_reel:
#             erreur = erreur + 1
#     return erreur/......

def taux_erreur():
    erreur = 0
    for i in range(len(donnees_test)):
        le_plus_proche = plus_proche(i)
        poste_predit = le_plus_proche[2]
        poste_reel = donnees_test[i][2]
        if poste_predit != poste_reel:
            erreur = erreur + 1
    return erreur/len(donnees_test)

print("taux erreur",taux_erreur())
# Out:
# taux erreur 0.4111111111111111

# %% [markdown]
# ## Algorithme des k plus proches voisins
# Plutôt que de regarder le plus proche voisin, nous allons regarder les k plus proches voisins du joueur de test dans les données d’entrainement.
#
# Pour cela nous allons créer une liste des postes des plus proches voisins, puis grâce à la fonction suivante, nous en déduirons le poste le plus probable d’après ces voisins.

# %%
def occurence_max(tab):
    "Renvoie la valeur qui a le plus d'occurences dans un tableau"
    dico = {k: 0 for k in tab}
    for k in tab:
        dico[k] += 1

    maxi, k_max = 0 , 0
    for k, v in dico.items():
        if v > maxi:
            maxi, k_max = v , k
    return k_max

assert occurence_max(["Avant", "Avant", "Arrière"]) == "Avant"
assert occurence_max(["Avant", "Arrière", "Arrière"]) == "Arrière"

# %%
def classification(k,donnees,taille,poids):
    plus_proches = []
    for donnee in donnees:
        d = distance((int(donnee[4]),int(donnee[5])),(taille,poids))
        plus_proches.append((d,donnee[2]))
    plus_proches =sorted(plus_proches,key= lambda x: x[0],reverse=False)
    plus_proches =plus_proches[:k]
    plus_proches = [pp[1] for pp in plus_proches]
    return occurence_max(plus_proches)

# %% [markdown]
# <u>Commentaires sur cette fonction</u> :
#
#
# *   On construit une liste <code>plus_proches</code> constituée de triplets de la forme <code>(distance, poste)</code> ;
# *   Cette liste est triée à la ligne 7 par ordre de distance croissante ;
# *  A la ligne 7, on conserve les k plus proches voisins (les k dont la distance est la plus petite)
# * A la ligne 8, on cree une liste des k postes les plus proches
# * La ligne 9 permet de retourner le poste majoritaire parmi les k postes.

# %% [markdown]
# ### Taux d'erreur avec les k plus proches voisins

# %%
def taux_erreur_knn(k):
    erreur = 0
    for i in range(len(donnees_test)):
        taille = int(donnees_test[i][4])
        poids = int(donnees_test[i][5])
        poste_predit = classification(k,donnees_entrainement,taille,poids)
        poste_reel = donnees_test[i][2]
        if poste_predit != poste_reel:
            erreur = erreur + 1
    return erreur/len(donnees_test)

k = 7
print(f"taux erreur knn avec k = {k} : {taux_erreur_knn(k)}")
# Out:
# taux erreur knn avec k = 7 : 0.24444444444444444

# %% [markdown]
# ### Recherche de la meilleure valeur de k
# Nous allons tracer le taux d’erreur en fonction du nombre k de voisins choisis pour trouver la meilleure valeur de k possible.

# %%
xs = []
ys = []
for k in range(1, len(donnees_entrainement)):
    taux_erreur = taux_erreur_knn(k)
    xs.append(k)
    ys.append(round(taux_erreur*100, 1))

plt.plot(xs, ys)
plt.xlabel('k')
plt.ylabel("% d'erreur")
plt.title(f"Le meilleur résultat ({min(ys)}% d'erreur) est obtenu avec {xs[ys.index(min(ys))]} voisins")
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
